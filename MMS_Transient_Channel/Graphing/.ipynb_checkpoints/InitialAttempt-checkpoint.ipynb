# %%
import matplotlib.pyplot as plt
from IPython.display import display
import sys
import pandas as pd

# %%
# Add the Results folders of the different components
# Forward Problem
FP_dir = '/home/sirush/PhDResearch/MMS_Transient_Channel/ForwardProblem/Log_Files/'

# %%
# Begin by reading in the data from the forward problem
forward_problem_log = 'log_Re{1,20,40,60,80,100}_nxnt{24,36,48,60,72}_short.txt'
forward_probem_data = pd.read_csv(FP_dir+forward_problem, sep=' ')

# %%
forward_probem_data
# Out:
#     tFinal   Re  nx  nt      uErr      pErr    runtime
# 0        1    1  24  24  0.000040  0.001322    81.3056
# 1        1    1  36  36  0.000012  0.002166   322.6750
# 2        1    1  48  48  0.000005  0.004427   849.6280
# 3        1    1  60  60  0.000003  0.014252  1998.2900
# 4        1    1  72  72  0.000002  0.019729  3849.0700
# 5        1   20  24  24  0.000064  0.000068    65.1414
# 6        1   20  36  36  0.000028  0.000129   213.5700
# 7        1   20  48  48  0.000016  0.000335   532.0930
# 8        1   20  60  60  0.000010  0.000599  1095.3500
# 9        1   20  72  72  0.000007  0.001055  1984.0500
# 10       1   40  24  24  0.000094  0.000046    63.2143
# 11       1   40  36  36  0.000044  0.000351   203.2090
# 12       1   40  48  48  0.000025  0.000503   494.2280
# 13       1   40  60  60  0.000016  0.000259  1031.0500
# 14       1   40  72  72  0.000012  0.000535  1849.2100
# 15       1   60  24  24  0.000125  0.000041    61.7663
# 16       1   60  36  36  0.000056  0.000490   198.0230
# 17       1   60  48  48  0.000032  0.000732   479.9110
# 18       1   60  60  60  0.000021  0.000870   985.8670
# 19       1   60  72  72  0.000015  0.000461  1793.0400
# 20       1   80  24  24  0.000157  0.000039    62.1908
# 21       1   80  36  36  0.000068  0.000183   196.3240
# 22       1   80  48  48  0.000038  0.000817   471.1920
# 23       1   80  60  60  0.000024  0.001005   965.9490
# 24       1   80  72  72  0.000017  0.000434  1778.6800
# 25       1  100  24  24  0.000188  0.000038    60.1001
# 26       1  100  36  36  0.000078  0.000110   191.8580
# 27       1  100  48  48  0.000043  0.000573   457.9470
# 28       1  100  60  60  0.000027  0.001144   951.9260
# 29       1  100  72  72  0.000019  0.001126  1705.6100

# %%
for Re in forward_probem_data['Re'].unique():
    plt.plot(forward_probem_data['nx'].unique(),forward_probem_data[forward_probem_data['Re'].eq(Re)]['uErr'])
# plt.plot(forward_probem_data['nx'].unique(),forward_probem_data[forward_probem_data['Re'].eq(1)]['uErr'])

plt.xlabel('Spatial & Temporal Resolution')
plt.ylabel('$||u_{Ex}- u_{FP}||$')
plt.title('Accuracy of Viento')
plt.xticks(forward_probem_data['nx'].unique())
plt.ylim(0, 1.1*forward_probem_data['uErr'].max())
# plt.axis([40, 160, 0, 0.03])
plt.show()

# %%
# plt.ylim(plt.ylim()[0], 1.0)
plt.ylim(0, 1.1*forward_probem_data['uErr'].max())
# Out:
# (0, 0.0002072466)

# %%
for Re in forward_probem_data['Re'].unique():
    plt.plot(forward_probem_data['nx'].unique(),forward_probem_data[forward_probem_data['Re'].eq(Re)]['uErr'])
# plt.plot(forward_probem_data['nx'].unique(),forward_probem_data[forward_probem_data['Re'].eq(1)]['uErr'])

plt.xlabel('Spatial & Temporal Resolution')
plt.ylabel('$||u_{Ex}- u_{FP}||$')
plt.title('Accuracy of Viento')
plt.xticks(forward_probem_data['nx'].unique())
plt.ylim(0, 1.1*forward_probem_data['uErr'].max())
# plt.axis([40, 160, 0, 0.03])
plt.show()
